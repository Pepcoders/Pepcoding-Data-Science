# %% [markdown]
# #DATA SCIENCE
#
# ![Add a heading.png](data:image/png;base64,...)

# %% [markdown]
# #INTRO TO DATA SCIENCE
#
# ![1*mgXvzNcwfpnBawI6XTkVRg.png](data:image/png;base64,...)

# %% [markdown]
# Data science is an interdisciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from noisy, structured and unstructured data, and apply knowledge and actionable insights from data across a broad range of application domains.

# %% [markdown]
# # INTRODUCTION TO AI

# %% [markdown]
# “The science and engineering of making intelligent machines, especially intelligent computer programs”. -John McCarthy
#
#
#
# Artificial Intelligence is an approach to make a computer, a robot, or a product to think how smart human think. AI is a study of how human brain think, learn, decide and work, when it tries to solve problems. And finally this study outputs intelligent software systems.The aim of AI is to improve computer functions which are related to human knowledge, for example, reasoning, learning, and problem-solving.
#
# ![Relationship-between-AI-ML-DL-and-NLP-7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Machine Learning
#
# ML is a subset of AI that uses statistical learning algorithms to build smart systems. The ML systems can automatically learn and improve without explicitly being programmed. The recommendation systems on music and video streaming services are examples of ML. The machine learning algorithms are classified into three categories: supervised, unsupervised and reinforcement learning.
#
#
# In the ML module we'll be learning the following Algorithms firstly we'll be learning the maths behind it and then the implementation:
#
# 1. Linear Regression
# 2. Logistic Regression
# 3. SVM (Support Vector Machines)
# 4. Decision Trees
# 5. Ensemble Learning & Random Forest
# 6. Dimensionality Reduction
# 7. K-MEANS CLUSTERING
# 8. NAIVE BAYES
# 9. ANAMOLY
# 10. TIME SERIES
#
# Additional Topics
#
# 1. Multivariable Regression and Gradient Descent

# %% [markdown]
# # Deep Learning
#
# Deep learning is a type of machine learning and artificial intelligence (AI) that imitates the way humans gain certain types of knowledge. Deep learning is an important element of data science, which includes statistics and predictive modeling. It is extremely beneficial to data scientists who are tasked with collecting, analyzing and interpreting large amounts of data; deep learning makes this process faster and easier.
#
# The following are things we'll be learning in Deep Learning
#
# 1. Basic Intro to Neural Network
# 2. Vanishing/Exploding Gradient Problems
# 3. Different Activation Functions
# 4. Batch Normalization
# 5. Cost Function
# 6. Loss Function
# 7. Backward Propagation In Depth
# 8. Tensorflow In Depth
# 9. CNN Overview
# 10. Convolutional Layers , pooling , padding
#
# Now after this We'll be studying different CNN architectures
#
# 1. Le-Net
# 2. AlexNet
# 3. GoogleNet
# 4. VGG Net
# 5. ResNet
# 6. XceptionNet
#
# These are More topics to do
#
# 1. Implementation of ResNet 34 using Keras
# 2. Using Pretrained models from keras
# 3. FCN
# 4. YOLO
# 5. Semantic Segmentation

# %% [markdown]
# # Natural Language Processing
#
# Natural Language Processing (NLP) makes it possible for computers to understand the human language. Behind the scenes, NLP analyzes the grammatical structure of sentences and the individual meaning of words, then uses algorithms to extract meaning and deliver outputs. In other words, it makes sense of human language so that it can automatically perform different tasks.
#
# In NLP Module We'll be learning the following things
#
# 1. Processing Raw Texts
# 2. Text Normalization
# 3. Categorizing and Tagging Words
# 4. Frequency Distribution
# 5. Annotation and Tokenization
# 6. Extraxting Information from Text
#
# We'll be learning above all the things using below libraries
#
# 1. NLTK
# 2. Text Blob
# 3. Spacy
# 4. Stanford NLP
#
# Now After the Libraries we'll be learning
#
# 1. Word Embedding
# 2. RNN
# 3. LSTM
# 4. BI-LSTM
# 5. GRU
# 6. Attention Based Model
# 7. Transfer Learning in NLP
#
# # And Last but not the least We'll seeing how to make chatbots
# # and we'll be building one

# %% [markdown]
# #Thank YOU
