# %% [markdown]
# # Bias and Variance
#
# ![Alt text](./img.png "Optional Title")

# %% [markdown]
# #### this are two ways to fit the training set data
#
# ### The inability for a machine learning method (like linear regression in this case) to capture the true relationship is called Bias
#
# ### In machine learning the difference in fits between dataset is called Variance
#
#
# #### here the squiggly line has low Bias, since it's flexible and can adapt to the curve in the relationship between X-axis and Y-axis
# #### but has hight variability, because result in vastly different sum of square for different dataset.
#
# ### Because the squiggly line fits the training set really well, but not testing set, therefore, Squiggly line is Overfit
#
# ## An Ideal Model
# #### An accurate model should have low bias and low variability, by producing consistent predictions across different datasets
#
# #### and this is done by finding a sweet spot between simple and a complex model, three method for doing this area:
# * regularizationn
# * boosting
# * bagging (eg: Random Forest)
