# %% [markdown]
# # Python course outline...
#
#
# ## 1. Variables, Data Types
#
# #### basic input output in python
#
# ### 1.1. creating variables
#
# ### 1.2. assigning multiple values
#
# ### 1.3. global variables
#
# ### 1.4. different datatypes in python
# #### 1.4.1. set type are set and frozenset
# #### 1.4.2. map tpe is dict
# #### 1.4.3. etc
#
# ### 1.5. casting in python specific datatype
#
# ### 1.6. some arithmetic operations
#
#
# ## 2. Strings
#
# ### 2.1. slicing of string (note: negative indexing)
#
# ### 2.2. standard string modifiers
# #### 2.2.1 upper, lower
# #### 2.2.2. replace, split
#
# ### 2.3. concatination of string
# #### 2.3.1. cannot concatinate string with number
# #### 2.3.2. format function
#
#
# ## 3. Quick tour to conditions and loops
#
# ### 3.1. if...else
#
# ### 3.2. for loop
# #### 3.2.1. range method
#
# ### 3.3. while loop
#
# ### 3.4. break keyword, else keyword in loops, continue keyword
#
#
# ## 4. List
#
# ### 4.1. declaration normal and constructor method ( multidimensional list example )
#
# ### 4.2. indexing, length and adding multiple datatype in a list
#
# ### 4.3. check specific thing in list (`in` statement)
#
# ### 4.4. append, insert and extend methods
#
# ### 4.5. remove, pop, clear methods
#
# ### 4.6. for in loop in list
#
# ### 4.7. sort methode (note: reverse = True method also)
#
# ### 4.8. deep copy and shalow copy of list
#
#
# ## 5. Functions
#
# ### 5.1. quick walk through using any rec example
#
# ### 5.2. lambda functions
#
#
# ## 6. Error Handling
#
# ### 6.1. protective approch using if else
#
# ### 6.2. try and except
#
#
# ## 7. Tuples
#
# ### 7.1. declaration normal, constructor method and single valued tuple
#
# ### 7.2. diff. between tuples and list
#
# ### 7.3. indexing, length, insertion and deletion
#
# ### 7.4. unpacking of tuples ( using * method )
#
# ### 7.5. count and index method of tuple
#
#
# ## 8. Sets
#
# ### 8.1. difference between list, tuples, and sets
#
# ### 8.2. basic operations
#
#
# ## 9. Dictionary
#
# ### 9.1. Basic operations
#
# ### 9.2. get, keys, values methods
#
# ### 9.3. update, remove, nested dictionary
#
#
# ## 10. File Handling
#
# ### 10.1. read file
#
# ### 10.2. update file
#
# ### 10.3. remove file
#
#
# ## 11. Object Oriented Programming
#
# ### 11.1. classes and objects
#
# ### 11.2. scope
